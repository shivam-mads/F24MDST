# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for completion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>).
#
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
#read data from csv
raw = pd.read_csv('../data/states_edu.csv')
print(raw.shape)
print(raw.columns)
print(raw.count())
print(raw['YEAR'].unique())
raw.head(10)
# Out:
# (1715, 25)
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'GRADES_PK_G', 'GRADES_KG_G',
#        'GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G',
#        'GRADES_9_12_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')
# PRIMARY_KEY                     1715
# STATE                           1715
# YEAR                            1715
# ENROLL                          1224
# TOTAL_REVENUE                   1275
# FEDERAL_REVENUE                 1275
# STATE_REVENUE                   1275
# LOCAL_REVENUE                   1275
# TOTAL_EXPENDITURE               1275
# INSTRUCTION_EXPENDITURE         1275
# SUPPORT_SERVICES_EXPENDITURE    1275
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
#only include the required colums
req_cols = ['STATE','YEAR','AVG_READING_4_SCORE','AVG_MATH_4_SCORE','AVG_MATH_8_SCORE','GRADES_8_G','GRADES_4_G']
edu = raw[req_cols]
print(edu['YEAR'].unique())
# Out:
# [1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005
#  2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 1986 1987 1988
#  1989 1990 1991 2017 2019]

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen one of Grade 4 Reading, Grade 4 Math, or Grade 8 Math to focus on: *ENTER YOUR CHOICE HERE*

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
#Grade 8 math
print(edu['STATE'].unique())
edu['YEAR'].unique()
# Out:
# ['ALABAMA' 'ALASKA' 'ARIZONA' 'ARKANSAS' 'CALIFORNIA' 'COLORADO'
#  'CONNECTICUT' 'DELAWARE' 'DISTRICT_OF_COLUMBIA' 'FLORIDA' 'GEORGIA'
#  'HAWAII' 'IDAHO' 'ILLINOIS' 'INDIANA' 'IOWA' 'KANSAS' 'KENTUCKY'
#  'LOUISIANA' 'MAINE' 'MARYLAND' 'MASSACHUSETTS' 'MICHIGAN' 'MINNESOTA'
#  'MISSISSIPPI' 'MISSOURI' 'MONTANA' 'NEBRASKA' 'NEVADA' 'NEW_HAMPSHIRE'
#  'NEW_JERSEY' 'NEW_MEXICO' 'NEW_YORK' 'NORTH_CAROLINA' 'NORTH_DAKOTA'
#  'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'RHODE_ISLAND' 'SOUTH_CAROLINA'
#  'SOUTH_DAKOTA' 'TENNESSEE' 'TEXAS' 'UTAH' 'VERMONT' 'VIRGINIA'
#  'WASHINGTON' 'WEST_VIRGINIA' 'WISCONSIN' 'WYOMING' 'DODEA' 'NATIONAL']
# array([1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 1986, 1987, 1988, 1989, 1990, 1991, 2017, 2019])

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average across all years in the test you chose?

# %%
#pivot the table where index is year and column is state name then draw a graph
mich_ohio = edu[edu['STATE'].isin(['OHIO','MICHIGAN'])][['YEAR','STATE','AVG_MATH_8_SCORE']].pivot(index='YEAR',columns=['STATE'])
#drop datapoint where values are not known
mich_ohio.dropna(inplace=True)
# rename column for simplicity else has to pass tuple for name
mich_ohio.columns = ['MICHIGAN','OHIO']
#plot the data 
mich_ohio.plot()
plt.ylabel('SCORE')
plt.title('8th Grade Math Score MICHIGAN vs OHIO')

#Add a new column and populate statename whihc has higher math average 
mich_ohio['STATE_WITH_HIGH_AVG'] = mich_ohio[['MICHIGAN','OHIO']].apply(lambda x: 'MICHIGAN' if x['MICHIGAN']>x['OHIO'] else 'OHIO' ,axis=1)
mich_ohio['STATE_WITH_HIGH_AVG'].unique()
# Out:
# array(['OHIO'], dtype=object)

# %% [markdown]
# Find the average for your chosen test across all states in 2019

# %%
edu[edu['YEAR']==2019]['AVG_MATH_8_SCORE'].mean()
# Out:
# 281.2641509433962

# %% [markdown]
# For each state, find a maximum value for your chosen test score

# %%
res = edu[['AVG_MATH_8_SCORE','STATE']].groupby('STATE').max()
res.head()
# Out:
#             AVG_MATH_8_SCORE
# STATE
# ALABAMA                269.0
# ALASKA                 283.0
# ARIZONA                283.0
# ARKANSAS               279.0
# CALIFORNIA             277.0

# %% [markdown]
# *Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
edu  = raw[['YEAR','STATE','AVG_MATH_8_SCORE','GRADES_8_G','AVG_READING_8_SCORE','AVG_MATH_4_SCORE']]

# %% [markdown]
# Feature engineering justification: **<BRIEFLY DESCRIBE WHY YOU MADE THE CHANGES THAT YOU DID\>**

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
#MATH_8 score trend for last years for all stats
edu1 = edu.dropna(subset=['AVG_MATH_8_SCORE'])
edu1 = edu1[['YEAR','STATE','AVG_MATH_8_SCORE']].pivot(index='YEAR',columns='STATE')
edu1.dropna(inplace=True)

edu1.plot(figsize=(15,7))
plt.legend(bbox_to_anchor=(1.0, 1.0))
#plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# **<CAPTION FOR VIZ 1>**

# %% [markdown]
# **Visualization 2**

# %%
#Visualize math score accross the states 

edu1 = edu[['YEAR','AVG_MATH_8_SCORE']].dropna()
edu1.groupby('YEAR')["AVG_MATH_8_SCORE"].mean().plot()
plt.ylabel('SCORE')
plt.title('8th Grade Math Score Over Time')
# Out:
# Text(0.5, 1.0, '8th Grade Math Score Over Time')

# %%
edu.plot.scatter(x='AVG_MATH_8_SCORE', y='AVG_MATH_4_SCORE', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='AVG_MATH_8_SCORE', ylabel='AVG_MATH_4_SCORE'>

# %%
edu.plot.scatter(x='AVG_MATH_8_SCORE', y='AVG_READING_8_SCORE', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='AVG_MATH_8_SCORE', ylabel='AVG_READING_8_SCORE'>

# %% [markdown]
# **<CAPTION FOR VIZ 2>**

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
#Predict math 8 score based on reading 8 score , math 4 score and number of student enrolled
X = edu[['GRADES_8_G','AVG_READING_8_SCORE','AVG_MATH_4_SCORE']].dropna()
y = edu.loc[X.index]['AVG_MATH_8_SCORE']

# %%
X_train, X_test, y_train, y_test = train_test_split(
      X, y, test_size=.3, random_state=0)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
# import your sklearn class here
from sklearn.linear_model import LinearRegression

# %%
# create your model here
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(model.intercept_)
print(model.coef_)
# Out:
# -35.95802414406734
# [7.34029020e-07 5.42404916e-01 7.27763070e-01]

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
print(model.score(X_test, y_test))
print(np.mean(model.predict(X_test)-y_test))
np.mean((model.predict(X_test)-y_test)**2)**0.5
# Out:
# 0.9003996940070167
# 0.05664363322999427
# 2.7303784914384135

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = 'AVG_MATH_4_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('Math 8 score')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %%
col_name = 'AVG_MATH_4_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "blue")
plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

plt.legend(['True testing','Predicted testing'])
plt.xlabel(col_name)
plt.ylabel('Math 8 Score')
plt.title("Model Behavior on Testing Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior on Testing Set')
